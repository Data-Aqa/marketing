# %%
# importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import basedosdados as bd

# %%
bd.list_datasets()
# Out:
# dataset_id:
# 	br-cvm-oferta-publica-distribuicao
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-geobr-mapas
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-caged
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-indicadores
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-bd-diretorios-brasil
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-cvm-administradores-carteira
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-me-socios
# -----------------------------------------------------------------------------------------------
# dataset_id:
# 	br-poder360-pesquisas
# ...

# %%
bd.list_dataset_tables(dataset_id = 'br-me-comex-stat')
# Out:
# table_id:
# 	municipio_exportacao
# -----------------------------------------------------------------------------------------------
# table_id:
# 	municipio_importacao
# -----------------------------------------------------------------------------------------------
# table_id:
# 	ncm_exportacao
# -----------------------------------------------------------------------------------------------
# table_id:
# 	ncm_importacao
# -----------------------------------------------------------------------------------------------

# %%
bd.get_table_columns(dataset_id = 'br_me_comex_stat', table_id = 'municipio_exportacao')
# Out:
# name:
# 	ano
# bigquery_type:
# 	int64
# description:
# 	Ano
# temporal_coverage:
# 	[]
# covered_by_dictionary:
# 	no
# directory_column:
# 	{'dataset_id': 'br_bd_diretorios_data_tempo', 'table_id': 'ano', 'column_name':
#
# measurement_unit:
# 	year
# has_sensitive_data:
# 	no
# is_in_staging:
# 	True
# is_partition:
# 	True
# -----------------------------------------------------------------------------------------------
# name:
# 	mes
# bigquery_type:
# 	int64
# description:
# 	Mês
# temporal_coverage:
# 	[]
# covered_by_dictionary:
# 	no
# directory_column:
# 	{'dataset_id': 'br_bd_diretorios_data_tempo', 'table_id': 'mes', 'column_name':
#
# measurement_unit:
# 	month
# has_sensitive_data:
# 	no
# is_in_staging:
# 	True
# is_partition:
# 	True
# -----------------------------------------------------------------------------------------------
# name:
# 	id_sh4
# bigquery_type:
# 	string
# description:
# 	ID Sistema Harmonizado
# temporal_coverage:
# 	[]
# covered_by_dictionary:
# ...
